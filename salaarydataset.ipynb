# %% [markdown]
# <a href="https://colab.research.google.com/github/johnlaraji1608-collab/Linearregression_salarydata/blob/main/salaarydataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/Salary_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = df.drop("Unnamed: 0", axis='columns')

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
df.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.scatter(df['YearsExperience'],df['Salary'])
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('Scatterplot of Df')
# Out:
# Text(0.5, 1.0, 'Scatterplot of Df')

# %%
sns.pairplot(df)

# %%
X = df['YearsExperience']
y = df['Salary']
type(X)
type(y)
# Out:
# pandas.core.series.Series

# %%
np.array(X).shape
# Out:
# (30,)

# %%
X = df[['YearsExperience']]
y = df[['Salary']]
type(X)
np.array(X).shape
# Out:
# (30, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_417/4091313174.py in <cell line: 0>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=42)
#
# NameError: name 'X' is not defined

# %%
X_train.shape
# Out:
# (22, 1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit_transform(X_train)
scaler.transform(X_test)
# Out:
# array([[ 1.79640106],
#        [ 0.03908914],
#        [ 1.27294644],
#        [ 0.1886476 ],
#        [-0.59653431],
#        [-0.40958624],
#        [ 2.05812836],
#        [ 1.45989452]])

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression.coef_
regression.intercept_
# Out:
# array([24542.02582803])

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train, regression.predict(X_train))

# %%
y_pred = regression.predict(X_test)


#Checking its performance metrics
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)

from sklearn.metrics import r2_score
rmse = np.sqrt(mse)

from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test,y_pred)
r2score = r2_score(y_test,y_pred)
adj_r2 = 1 - (1- r2score)* (len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)


#Viewing performance metrics
print("MAE:", mae)
print("MSE:",mse)
print("RMSE:", rmse)
print("R2 Score:", r2score)
print("Adjusted R2 Score:", adj_r2)
# Out:
# MAE: 5056.995466663583
# MSE: 38802588.99247057
# RMSE: 6229.172416338351
# R2 Score: 0.9347210011126783
# Adjusted R2 Score: 0.9238411679647913
